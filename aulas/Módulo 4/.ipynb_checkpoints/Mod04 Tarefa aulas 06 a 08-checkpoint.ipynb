# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests
# Configurar para exibir mais linhas e colunas
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# Configurar para mostrar todo o conteúdo das colunas
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
url = 'http://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Estado'

# Fazendo a requisição HTTP GET
response = requests.get(url)

# Verificando se a requisição foi bem-sucedida
if response.status_code == 200:
    # Convertendo a resposta JSON para um dicionário Python
    data = response.json()
    
    # Convertendo o dicionário para um DataFrame do Pandas
    # A chave 'items' contém a lista de registros
    df = pd.json_normalize(data['items'])
    
    # Exibindo as primeiras linhas do DataFrame para verificar os dados carregados
    print(df.head(10))
else:
    print(f'Falha na requisição. Status code: {response.status_code}')
# Out:
#    id_pleito tipo_interessado     interessado  cod_ibge  uf num_pvl  \
# 0       8528           Estado  Rio de Janeiro        33  RJ    None
# 1       7057           Estado  Rio de Janeiro        33  RJ    None
# 2       7084           Estado  Rio de Janeiro        33  RJ    None
# 3      13624           Estado  Rio de Janeiro        33  RJ    None
# 4       7085           Estado  Rio de Janeiro        33  RJ    None
# 5       5516           Estado  Rio de Janeiro        33  RJ    None
# 6       7080           Estado  Rio de Janeiro        33  RJ    None
# 7       8556           Estado  Rio de Janeiro        33  RJ    None
# 8       9750           Estado  Rio de Janeiro        33  RJ    None
# 9      10002           Estado  Rio de Janeiro        33  RJ    None
#
#                                                   status  \
# 0                                               Deferido
# 1  Encaminhado à PGFN com manifestação técnica favorável
# 2  Encaminhado à PGFN com manifestação técnica favorável
# 3                                               Deferido
# 4  Encaminhado à PGFN com manifestação técnica favorável
# 5  Encaminhado à PGFN com manifestação técnica favorável
# 6  Encaminhado à PGFN com manifestação técnica favorável
# 7  Encaminhado à PGFN com manifestação técnica favorável
# 8                                               Deferido
# 9  Encaminhado à PGFN com manifestação técnica favorável
#
#            num_processo        data_protocolo  \
# 0  17944.000793/2009-56  2009-07-17T03:00:00Z
# 1  17944.000487/2014-87  2014-04-24T03:00:00Z
# 2  17944.000493/2010-19  2010-08-06T03:00:00Z
# 3  19405.000039/2002-72  2002-06-20T03:00:00Z
# 4  17944.000493/2012-72  2012-04-16T03:00:00Z
# 5  17944.000131/2011-09  2011-06-30T03:00:00Z
# 6  17944.000492/2012-28  2012-04-16T03:00:00Z
# 7  17944.000797/2010-78  2011-06-30T03:00:00Z
# 8  17944.001046/2006-92  2006-07-07T03:00:00Z
# 9  17944.001097/2009-67  2009-09-09T03:00:00Z
#
#                                          tipo_operacao  \
# 0                          Operação contratual interna
# 1  Operação contratual interna (com garantia da União)
# 2  Operação contratual externa (com garantia da União)
# 3                          Operação contratual interna
# 4  Operação contratual externa (com garantia da União)
# 5  Operação contratual externa (com garantia da União)
# 6  Operação contratual externa (com garantia da União)
# 7  Operação contratual externa (com garantia da União)
# 8                          Operação contratual interna
# 9  Operação contratual externa (com garantia da União)
#
#                                                       finalidade  \
# 0  Aquisição de terrenos, imóveis e/ou construção de instalações
# 1                                                 Infraestrutura
# 2                                   Fortalecimento Institucional
# 3                                                 Infraestrutura
# 4                                                 Infraestrutura
# 5                                    Desenvolvimento sustentável
# 6                                                 Multissetorial
# 7                                                 Multissetorial
# 8                                                 Infraestrutura
# 9                                                       Profisco
#
#                             tipo_credor  \
# 0       Instituição Financeira Nacional
# 1       Instituição Financeira Nacional
# 2  Instituição Financeira Internacional
# 3       Instituição Financeira Nacional
# 4  Instituição Financeira Internacional
# 5  Instituição Financeira Internacional
# 6  Instituição Financeira Internacional
# 7  Instituição Financeira Internacional
# 8       Instituição Financeira Nacional
# 9  Instituição Financeira Internacional
#
#                                                     credor          moeda  \
# 0     Banco Nacional de Desenvolvimento Econômico e Social           Real
# 1     Banco Nacional de Desenvolvimento Econômico e Social           Real
# 2  Banco Internacional para Reconstrução e Desenvolvimento  Dólar dos EUA
# 3     Banco Nacional de Desenvolvimento Econômico e Social           Real
# 4                             Corporação Andina de Fomento  Dólar dos EUA
# 5  Banco Internacional para Reconstrução e Desenvolvimento  Dólar dos EUA
# 6  Banco Internacional para Reconstrução e Desenvolvimento  Dólar dos EUA
# 7                  Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 8     Banco Nacional de Desenvolvimento Econômico e Social           Real
# 9                  Banco Interamericano de Desenvolvimento  Dólar dos EUA
#
#           valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0  1.570000e+08                 1                      0  24/07/2009
# 1  3.000000e+09                 1                      0  04/07/2014
# 2  1.867300e+07                 1                      0  19/08/2010
# 3  6.748240e+07                 1                      0  27/06/2002
# 4  1.206660e+08                 1                      0  04/10/2012
# 5  4.850000e+08                 1                      0  04/07/2011
# 6  3.000000e+08                 1                      0  03/09/2012
# 7  1.120000e+08                 1                      0  04/07/2011
# 8  3.057373e+08                 1                      0  13/07/2006
# 9  1.975905e+07                 1                      0  28/09/2009

# %%
# 2) Seu código aqui
df['status'].value_counts()
# Out:
# status
# Encaminhado à PGFN com manifestação técnica favorável    34
# Deferido                                                 14
# Arquivado a pedido                                        3
# Arquivado por decurso de prazo                            1
# Name: count, dtype: int64

# %%
# 3) Seu código aqui 
# df['ano_status'] = df['data_status'].dt.year
print(df['data_status'].dtype)
df['ano_status'] = df['data_status'].astype(str).str[:4]
df['ano_status'].head(10)
# Out:
# object
# 0    24/0
# 1    04/0
# 2    19/0
# 3    27/0
# 4    04/1
# 5    04/0
# 6    03/0
# 7    04/0
# 8    13/0
# 9    28/0
# Name: ano_status, dtype: object

# %%
# 4) Seu código aqui
# Contar a frequência de cada ano na variável 'ano_status'
frequencia_anos = df['ano_status'].value_counts()

# Exibir a frequência de cada ano
print(frequencia_anos)
# Out:
# ano_status
# 06/0    5
# 04/0    5
# 27/0    4
# 01/0    4
# 04/1    3
# 28/0    3
# 25/1    2
# 18/0    2
# 07/0    2
# 27/1    2
# 29/0    2
# 14/0    2
# 10/0    2
# 22/0    1
# 24/0    1
# 21/1    1
# 11/0    1
# 20/1    1
# 05/0    1
# 20/0    1
# 02/0    1
# 09/1    1
# 26/0    1
# 13/0    1
# 03/0    1
# 19/0    1
# 16/0    1
# Name: count, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui
def baixar_dataframe_uf(uf):
    url = f'http://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf={uf}&tipo_interessado=Estado'
    response = requests.get(url)# Verificando se a requisição foi bem-sucedida
    
    if response.status_code == 200:
        # Convertendo a resposta JSON para um dicionário Python
        data = response.json()
        
        # Convertendo o dicionário para um DataFrame do Pandas
        # A chave 'items' contém a lista de registros
        df = pd.json_normalize(data['items'])
        
        # Exibindo as primeiras linhas do DataFrame para verificar os dados carregados
        print(df.head(10))
    else:
        print(f'Falha na requisição. Status code: {response.status_code}')

baixar_dataframe_uf('DF')
# Out:
#    id_pleito tipo_interessado       interessado  cod_ibge  uf  \
# 0       9367           Estado  Distrito Federal        53  DF
# 1      11365           Estado  Distrito Federal        53  DF
# 2       7248           Estado  Distrito Federal        53  DF
# 3       6650           Estado  Distrito Federal        53  DF
# 4      22390           Estado  Distrito Federal        53  DF
# 5      10713           Estado  Distrito Federal        53  DF
# 6       6726           Estado  Distrito Federal        53  DF
# 7       9946           Estado  Distrito Federal        53  DF
# 8       4940           Estado  Distrito Federal        53  DF
# 9      11564           Estado  Distrito Federal        53  DF
#
#                 num_pvl  \
# 0                  None
# 1                  None
# 2                  None
# 3                  None
# 4  00000.000000/2031-15
# 5                  None
# 6                  None
# 7                  None
# 8                  None
# 9                  None
#
#                                                   status  \
# 0                                              Arquivado
# 1                                               Deferido
# 2                                     Arquivado a pedido
# 3                                               Deferido
# 4                                     Arquivado a pedido
# 5                                               Deferido
# 6                                               Deferido
# 7                                             Indeferido
# 8  Encaminhado à PGFN com manifestação técnica favorável
# 9                                               Deferido
#
#            num_processo        data_protocolo  \
# 0  17944.000966/2006-93  2006-07-04T03:00:00Z
# 1  17944.001423/2012-31  2012-12-26T02:00:00Z
# 2  17944.000530/2009-47  2012-04-16T03:00:00Z
# 3  17944.000402/2002-27  2002-06-19T03:00:00Z
# 4  17944.000564/2016-61  2016-06-27T03:00:00Z
# 5  17944.001266/2010-01  2011-05-27T03:00:00Z
# 6  17944.000417/2008-81  2009-04-22T03:00:00Z
# 7  17944.001085/2006-90  2006-07-07T03:00:00Z
# 8  17944.000001/2013-20  2015-01-28T02:00:00Z
# 9  17944.001478/2007-84  2007-11-30T02:00:00Z
#
#                                          tipo_operacao  \
# 0                          Operação contratual interna
# 1                          Operação contratual interna
# 2  Operação contratual externa (com garantia da União)
# 3                          Operação contratual interna
# 4  Operação contratual interna (com garantia da União)
# 5                          Operação contratual interna
# 6                          Operação contratual interna
# 7                          Operação contratual interna
# 8  Operação contratual interna (com garantia da União)
# 9                          Operação contratual interna
#
#                                        finalidade  \
# 0                                  Infraestrutura
# 1                             PAC - Contrapartida
# 2                                  Infraestrutura
# 3  Aquisição de máquinas, equipamentos e veículos
# 4                                  Infraestrutura
# 5                                           PNAFM
# 6                         PAC - Saneamento - 2008
# 7  Aquisição de máquinas, equipamentos e veículos
# 8                                      Proinveste
# 9                        PAC - Pró-Moradia - 2008
#
#                             tipo_credor  \
# 0       Instituição Financeira Nacional
# 1       Instituição Financeira Nacional
# 2  Instituição Financeira Internacional
# 3       Instituição Financeira Nacional
# 4       Instituição Financeira Nacional
# 5       Instituição Financeira Nacional
# 6       Instituição Financeira Nacional
# 7       Instituição Financeira Nacional
# 8       Instituição Financeira Nacional
# 9       Instituição Financeira Nacional
#
#                                                  credor          moeda  \
# 0                               Caixa Econômica Federal           Real
# 1                               Caixa Econômica Federal           Real
# 2                   Agência Francesa de Desenvolvimento           Euro
# 3                                   Banco do Brasil S/A  Dólar dos EUA
# 4                                   Banco do Brasil S/A           Real
# 5                               Caixa Econômica Federal           Real
# 6                               Caixa Econômica Federal           Real
# 7                                   Banco do Brasil S/A           Iene
# 8  Banco Nacional de Desenvolvimento Econômico e Social           Real
# 9                               Caixa Econômica Federal           Real
#
#           valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0  1.799934e+08                 0                      0  24/07/2007
# 1  4.500000e+07                 1                      0  28/12/2012
# 2  1.340000e+08                 0                      0  21/05/2012
# 3  1.869741e+07                 0                      0  03/07/2002
# 4  4.997500e+07                 0                      0  05/07/2017
# 5  2.938243e+07                 1                      0  16/06/2011
# 6  9.100000e+07                 1                      0  30/04/2009
# 7  1.439500e+09                 0                      0  21/07/2006
# 8  3.111526e+08                 1                      0  01/02/2013
# 9  1.799934e+08                 1                      0  11/12/2007

# %%
# 2) Seu código aqui
baixar_dataframe_uf('MG')
df['status'].value_counts()

# Arquivado por decurso de prazo = 1
# Out:
#    id_pleito tipo_interessado   interessado  cod_ibge  uf  \
# 0       5828           Estado  Minas Gerais        31  MG
# 1       9197           Estado  Minas Gerais        31  MG
# 2      68204           Estado  Minas Gerais        31  MG
# 3      13672           Estado  Minas Gerais        31  MG
# 4      13587           Estado  Minas Gerais        31  MG
# 5      13695           Estado  Minas Gerais        31  MG
# 6      20458           Estado  Minas Gerais        31  MG
# 7      22380           Estado  Minas Gerais        31  MG
# 8      13447           Estado  Minas Gerais        31  MG
# 9       7002           Estado  Minas Gerais        31  MG
#
#                 num_pvl  \
# 0                  None
# 1                  None
# 2  PVL02.003861/2023-24
# 3                  None
# 4                  None
# 5                  None
# 6  00000.000000/2020-68
# 7  00000.000000/2031-07
# 8                  None
# 9                  None
#
#                                                   status  \
# 0  Encaminhado à PGFN com manifestação técnica favorável
# 1  Encaminhado à PGFN com manifestação técnica favorável
# 2                        Em retificação pelo interessado
# 3  Encaminhado à PGFN com manifestação técnica favorável
# 4  Encaminhado à PGFN com manifestação técnica favorável
# 5                                              Arquivado
# 6                                     Arquivado a pedido
# 7                                     Arquivado pela STN
# 8  Encaminhado à PGFN com manifestação técnica favorável
# 9  Encaminhado à PGFN com manifestação técnica favorável
#
#            num_processo        data_protocolo  \
# 0  17944.000208/2013-02  2013-07-16T03:00:00Z
# 1  17944.000924/2009-03  2010-03-10T03:00:00Z
# 2  17944.001186/2024-42  2024-03-19T14:59:50Z
# 3  19405.000048/2005-14  2005-12-28T02:00:00Z
# 4  19405.000031/2004-78  2004-11-27T02:00:00Z
# 5  19405.000053/2003-57  2003-08-25T03:00:00Z
# 6  17944.001085/2015-81  2015-11-23T02:00:00Z
# 7  17944.000547/2016-23  2016-12-21T02:00:00Z
# 8  19405.000002/2006-78  2009-02-02T02:00:00Z
# 9  17944.000477/2010-18  2010-05-24T03:00:00Z
#
#                                          tipo_operacao  \
# 0  Operação contratual interna (com garantia da União)
# 1  Operação contratual externa (com garantia da União)
# 2                                Concessão de garantia
# 3  Operação contratual externa (com garantia da União)
# 4  Operação contratual externa (com garantia da União)
# 5  Operação contratual externa (com garantia da União)
# 6  Operação contratual externa (com garantia da União)
# 7  Operação contratual interna (com garantia da União)
# 8  Operação contratual externa (com garantia da União)
# 9  Operação contratual interna (com garantia da União)
#
#                                                      finalidade  \
# 0                                                Infraestrutura
# 1                                                Infraestrutura
# 2        Concessão de garantia a empresa estatal não dependente
# 3                                                Multissetorial
# 4                                         Desenvolvimento rural
# 5                                                Infraestrutura
# 6                                                Multissetorial
# 7                                            Aditivo contratual
# 8                                                Infraestrutura
# 9  PEF - Programa Emergencial de Financiamento dos Estados/DF 2
#
#                             tipo_credor  \
# 0       Instituição Financeira Nacional
# 1  Instituição Financeira Internacional
# 2  Instituição Financeira Internacional
# 3  Instituição Financeira Internacional
# 4  Instituição Financeira Internacional
# 5  Instituição Financeira Internacional
# 6  Instituição Financeira Internacional
# 7       Instituição Financeira Nacional
# 8  Instituição Financeira Internacional
# 9       Instituição Financeira Nacional
#
#                                                     credor          moeda  \
# 0                                      Banco do Brasil S/A           Real
# 1                  Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 2                                     New Development Bank  Dólar dos EUA
# 3  Banco Internacional para Reconstrução e Desenvolvimento  Dólar dos EUA
# 4  Banco Internacional para Reconstrução e Desenvolvimento  Dólar dos EUA
# 5  Banco Internacional para Reconstrução e Desenvolvimento  Dólar dos EUA
# 6                  Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 7                                      Banco do Brasil S/A           Real
# 8                  Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 9     Banco Nacional de Desenvolvimento Econômico e Social           Real
#
#           valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0  1.500000e+09                 1                      0  12/08/2013
# 1  5.000000e+07                 1                      0  01/04/2010
# 2  2.000000e+08                 0                      0  03/04/2024
# 3  1.700000e+08                 1                      0  19/04/2006
# 4  3.500000e+07                 1                      0  09/12/2004
# 5  3.500000e+07                 0                      0  20/02/2004
# 6  5.000000e+07                 0                      0  29/04/2016
# 7  6.985602e+08                 0                      0  16/10/2017
# 8  1.000000e+07                 1                      0  12/11/2009
# 9  2.672700e+08                 1                      0  17/06/2010
# status
# Encaminhado à PGFN com manifestação técnica favorável    34
# Deferido                                                 14
# Arquivado a pedido                                        3
# Arquivado por decurso de prazo                            1
# Name: count, dtype: int64

# %%
# 3) Seu código aqui
baixar_dataframe_uf('BA')
# Filtrar o DataFrame para incluir apenas os registros com status "Deferido"
#deferidos = df[df['status'] == 'Deferido']

# Contar a ocorrência de "Deferido" por município
#deferidos_por_municipio = deferidos.groupby('interessado').size()

# Exibir o resultado
#print(deferidos_por_municipio)
# Contar a ocorrência de cada valor na coluna 'interessado'
df['interessado'].value_counts()

# Exibir o resultado
print(ocorrencia_interessado)
# Out:
#    id_pleito tipo_interessado interessado  cod_ibge  uf               num_pvl  \
# 0       6768           Estado       Bahia        29  BA                  None
# 1       7078           Estado       Bahia        29  BA                  None
# 2      23723           Estado       Bahia        29  BA  PVL02.000640/2016-75
# 3      22572           Estado       Bahia        29  BA  00000.000000/2032-81
# 4      18495           Estado       Bahia        29  BA                  None
# 5      18372           Estado       Bahia        29  BA                  None
# 6      18527           Estado       Bahia        29  BA                  None
# 7       8858           Estado       Bahia        29  BA                  None
# 8      18591           Estado       Bahia        29  BA                  None
# 9      18589           Estado       Bahia        29  BA                  None
#
#                                                   status  \
# 0  Encaminhado à PGFN com manifestação técnica favorável
# 1                                               Deferido
# 2  Encaminhado à PGFN com manifestação técnica favorável
# 3                                     Arquivado pela STN
# 4                                               Deferido
# 5                                               Deferido
# 6                                               Deferido
# 7  Encaminhado à PGFN com manifestação técnica favorável
# 8                                               Deferido
# 9                                               Deferido
#
#            num_processo        data_protocolo  \
# 0  17944.000425/2010-41  2011-11-25T02:00:00Z
# 1  17944.000492/2008-41  2008-03-24T03:00:00Z
# 2  17944.001273/2016-90  2017-06-06T18:33:06Z
# 3  17944.000644/2016-16  2016-09-08T03:00:00Z
# 4  19407.000035/2002-74  2002-06-26T03:00:00Z
# 5  19407.000009/2005-99  2005-06-30T03:00:00Z
# 6  19407.000043/2002-11  2002-06-21T03:00:00Z
# 7  17944.000853/2014-06  2014-07-10T03:00:00Z
# 8  19407.000059/2002-23  2002-06-21T03:00:00Z
# 9  19407.000058/2004-41  2005-11-11T02:00:00Z
#
#                                          tipo_operacao  \
# 0  Operação contratual externa (com garantia da União)
# 1                          Operação contratual interna
# 2  Operação contratual interna (com garantia da União)
# 3  Operação contratual externa (com garantia da União)
# 4                          Operação contratual interna
# 5                          Operação contratual interna
# 6                          Operação contratual interna
# 7  Operação contratual externa (com garantia da União)
# 8                          Operação contratual interna
# 9                          Operação contratual interna
#
#                             finalidade                           tipo_credor  \
# 0                       Infraestrutura  Instituição Financeira Internacional
# 1             PAC - Pró-Moradia - 2008       Instituição Financeira Nacional
# 2                       Infraestrutura       Instituição Financeira Nacional
# 3                       Infraestrutura  Instituição Financeira Internacional
# 4  Preservação e recuperação ambiental       Instituição Financeira Nacional
# 5                    Segurança pública       Instituição Financeira Nacional
# 6                    Saneamento básico       Instituição Financeira Nacional
# 7                       Infraestrutura  Instituição Financeira Internacional
# 8                    Saneamento básico       Instituição Financeira Nacional
# 9                       Multissetorial       Instituição Financeira Nacional
#
#                                                     credor          moeda  \
# 0  Banco Internacional para Reconstrução e Desenvolvimento  Dólar dos EUA
# 1                                  Caixa Econômica Federal           Real
# 2                                      Banco do Brasil S/A           Real
# 3                            Banco Europeu de Investimento  Dólar dos EUA
# 4                                  Caixa Econômica Federal           Real
# 5                                      Banco do Brasil S/A  Dólar dos EUA
# 6                                  Caixa Econômica Federal           Real
# 7  Banco Internacional para Reconstrução e Desenvolvimento  Dólar dos EUA
# 8                                  Caixa Econômica Federal           Real
# 9                          Banco do Nordeste do Brasil S/A  Dólar dos EUA
#
#           valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0  6.000000e+07                 1                      0  15/12/2011
# 1  5.299749e+07                 1                      0  09/04/2008
# 2  6.000000e+08                 1                      1  12/06/2017
# 3  2.000000e+08                 0                      0  11/01/2019
# 4  3.688700e+07                 1                      0  08/07/2002
# 5  1.616050e+07                 1                      0  26/07/2005
# 6  8.626204e+06                 1                      0  05/07/2002
# 7  4.000000e+08                 1                      0  16/07/2014
# 8  6.779155e+06                 1                      0  03/07/2002
# 9  1.400000e+07                 1                      0  08/12/2005
# interessado
# Rio de Janeiro    52
# Name: count, dtype: int64

# %%
# 4) Seu código aqui
